# %%
import pandas as pd
pd.Series.unique
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv")

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
len(df)
# Out:
# 158

# %%
df.isnull()
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      False   False           False            False           False
# 1      False   False           False            False           False
# 2      False   False           False            False           False
# 3      False   False           False            False           False
# 4      False   False           False            False           False
# ..       ...     ...             ...              ...             ...
# 153    False   False           False            False           False
# 154    False   False           False            False           False
# 155    False   False           False            False           False
# 156    False   False           False            False           False
# 157    False   False           False            False           False
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Find Duplicate

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 153    False
# 154    False
# 155    False
# 156    False
# 157    False
# Length: 158, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Finding Unique Values

# %%
unique_values = df["Country"].unique() ,
df["Region"].unique(),
df["Happiness Rank"].unique(),
df["Happiness Score"].unique(),
df["Standard Error"].unique(),
df["Economy (GDP per Capita)"].unique(),
df["Family"],
df["Health (Life Expectancy)"].unique(),
df["Freedom"].unique(),
df["Trust (Government Corruption)"].unique(),
df["Generosity"].unique(),
df["Dystopia Residual"].unique()
# Out:
# array([2.51738, 2.70201, 2.49204, 2.46531, 2.45176, 2.61955, 2.4657 ,
#        2.37119, 2.26425, 2.26646, 3.08854, 3.17728, 2.5332 , 3.60214,
#        2.51011, 3.26001, 1.96961, 1.9757 , 2.41484, 2.24743, 1.96994,
#        2.47489, 3.19131, 1.88501, 2.84848, 2.11569, 2.67585, 1.55674,
#        2.21126, 2.836  , 2.67782, 2.32142, 2.85737, 2.31945, 2.43872,
#        2.12367, 1.6488 , 2.32323, 1.87634, 2.79094, 2.26882, 3.035  ,
#        2.74255, 2.23741, 2.24639, 1.68435, 2.21978, 2.53942, 1.73797,
#        2.02518, 2.82334, 3.10712, 2.18896, 2.24729, 1.61583, 2.44649,
#        2.32407, 2.5945 , 2.1309 , 1.86565, 1.88541, 2.75414, 2.09066,
#        2.27394, 2.32038, 1.59888, 1.88931, 2.43209, 2.76579, 1.86984,
#        1.76145, 0.65429, 1.58782, 1.86399, 2.20173, 2.08528, 2.2327 ,
#        2.89319, 1.63794, 2.00073, 3.10709, 1.87996, 2.10017, 1.8604 ,
#        2.6343 , 1.93129, 2.025  , 1.26462, 1.62215, 1.7536 , 2.11032,
# ...

# %%
unique_values
# Out:
# (array(['Switzerland', 'Iceland', 'Denmark', 'Norway', 'Canada', 'Finland',
#         'Netherlands', 'Sweden', 'New Zealand', 'Australia', 'Israel',
#         'Costa Rica', 'Austria', 'Mexico', 'United States', 'Brazil',
#         'Luxembourg', 'Ireland', 'Belgium', 'United Arab Emirates',
#         'United Kingdom', 'Oman', 'Venezuela', 'Singapore', 'Panama',
#         'Germany', 'Chile', 'Qatar', 'France', 'Argentina',
#         'Czech Republic', 'Uruguay', 'Colombia', 'Thailand',
#         'Saudi Arabia', 'Spain', 'Malta', 'Taiwan', 'Kuwait', 'Suriname',
#         'Trinidad and Tobago', 'El Salvador', 'Guatemala', 'Uzbekistan',
#         'Slovakia', 'Japan', 'South Korea', 'Ecuador', 'Bahrain', 'Italy',
#         'Bolivia', 'Moldova', 'Paraguay', 'Kazakhstan', 'Slovenia',
#         'Lithuania', 'Nicaragua', 'Peru', 'Belarus', 'Poland', 'Malaysia',
#         'Croatia', 'Libya', 'Russia', 'Jamaica', 'North Cyprus', 'Cyprus',
# ...

# %% [markdown]
# EDA

# %%
import seaborn as sns

# %%
sns.scatterplot(x = "Country", y = "Happiness Score", data = df)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Happiness Score'>

# %%
sns.scatterplot(x = "Region", y = "Happiness Score", data = df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Happiness Score'>

# %%
sns.scatterplot(x = "Happiness Rank", y = "Happiness Score", data = df)
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Happiness Score'>

# %%
sns.scatterplot(x = "Standard Error", y = "Happiness Score", data = df)
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Happiness Score'>

# %%
sns.scatterplot(x = "Family", y = "Happiness Score", data = df)
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Happiness Score'>

# %%
sns.scatterplot(x = "Health (Life Expectancy)", y = "Happiness Score", data = df)
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Happiness Score'>

# %%
sns.scatterplot(x = "Freedom", y = "Happiness Score", data = df)
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Happiness Score'>

# %%
sns.scatterplot(x = "Trust (Government Corruption)", y = "Happiness Score", data = df)
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Happiness Score'>

# %%
sns.scatterplot(x = "Generosity", y = "Happiness Score", data = df)
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Happiness Score'>

# %%
sns.scatterplot(x = "Dystopia Residual", y = "Happiness Score", data = df)
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Happiness Score'>

# %%
import matplotlib.pyplot as plt
sns.pairplot(df)
plt.savefig('pairplot.png')
plt.show()

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
df.corr()['Happiness Score'].sort_values()
# Out:
# Happiness Rank                  -0.992105
# Standard Error                  -0.177254
# Generosity                       0.180319
# Trust (Government Corruption)    0.395199
# Dystopia Residual                0.530474
# Freedom                          0.568211
# Health (Life Expectancy)         0.724200
# Family                           0.740605
# Economy (GDP per Capita)         0.780966
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot = True, linewidth = 0.5, linecolor = "black", fmt = '.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outcome:
# The columns of the datset has mixed results with target column, 7 columns being positively correlated and 2 columns being negatively correlated.
#
# 1.  Happiness Rank has -99 percent correlation with the target column which is can be considered as negative correlation
# 2.  Standard Error has -7 percent correlation with the target column which is can be considered as negative correlation with weak bond
# 3.  Generosity has 18 percent correlation with the target column which is can be considered as a good bond
# 4.  Trust in Government has 39 percent correlation with the target column which is can be considered as a good bond
# 5.  Distopia Residual has 53 percent correlation with the target column which is can be considered as a good bond
# 6.  Freedom has 56 percent correlation with the target column which is can be considered as a good bond
# 7.  Health has 72 percent correlation with the target column which is can be considered as a good bond
# 8.  Family has 74 percent correlation with the target column which is can be considered as a good bond
# 9.  Economy has 78 percent correlation with the target column which is can be considered as a good bond
#
# Max Correlation : Economy(GDP Per Capita)
#
# Min Correlation :

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(), 2), linewidth = 2, annot= False, fmt= "f")
plt.xticks(fontsize=18)
plt.yticks(fontsize =12)
plt.title("Variables Summary")
plt.savefig("heatmap.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Total number of rows in the datasets:
# 1. 158 rows
# 2. 12 columns
#
# Happiness Rank
#
# 1. Mean = 79.493671
# 2. Std = 45.754363
# 3. max_value = 158.000000
# 4. min_value = 1.000000
#
# Happiness Score
#
# 1. Mean = 5.375734
# 2. Std = 1.145010
# 3. max_value = 7.587000
# 4. min_value = 2.839000
#
# Standard Error
#
# 1. Mean = 0.047885
# 2. Std = 0.017146
# 3. max_value = 0.136930
# 4. min_value = 0.018480
#
# Economy (GDP per Capita)
#
# 1. Mean = 0.846137
# 2. Std = 0.403121
# 3. max_value = 1.690420
# 4. min_value = 0.000000
#
# Family
#
# 1. Mean = 0.991046
# 2. Std = 0.272369
# 3. max_value = 1.402230
# 4. min_value = 0.000000
#
# Health (Life Expectancy)
#
# 1. Mean = 0.630259
# 2. Std = 0.247078
# 3. max_value = 1.025250
# 4. min_value = 0.000000
#
# Freedom
#
# 1. Mean = 0.428615
# 2. Std = 0.150693
# 3. max_value = 0.669730
# 4. min_value = 0.000000
#
# Trust (Government Corruption)
#
# 1. Mean = 0.143422
# 2. Std = 0.120034
# 3. max_value = 0.551910
# 4. min_value = 0.000000
#
# Generosity
#
# 1. Mean = 0.237296
# 2. Std = 0.126685
# 3. max_value = 0.795880
# 4. min_value = 0.000000
#
# Dystopia Residual
#
# 1. Mean = 2.098977
# 2. Std = 0.553550
# 3. max_value = 3.602140
# 4. min_value = 0.328580

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
collist = df.columns.values
ncol = 30
nrows = 14

# %%
collist
# Out:
# array(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual'],
#       dtype=object)

# %%
len(list(range(0,len(collist))))
# Out:
# 12

# %%
type(collist)
# Out:
# numpy.ndarray

# %%
plt.figure(figsize =(ncol, 3*ncol))
for i in range (2, len(collist)):
    plt.subplot(nrows, ncol, i+1)
    sns.boxenplot(data = df[collist[i]], color = 'green', orient= 'v')
    plt.tight_layout()

# %% [markdown]
# From the above outcome column "Happiness Rank" has less outliers compare to the other columns

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# Outcome of the skewness: Skewness threshold is taken +/- 0.50. Below are the columns which are having skewness:
#
# Standard Error
# Economy
# Family
# Health
# Trust
# Generosity
# Dystopia Residual

# %%
sns.distplot(df["Standard Error"])
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %%
sns.distplot(df["Happiness Rank"])
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Density'>

# %%
sns.distplot(df["Happiness Score"])
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Density'>

# %%
sns.distplot(df["Economy (GDP per Capita)"])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(df["Family"])
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
sns.distplot(df["Health (Life Expectancy)"])
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.distplot(df["Freedom"])
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %%
sns.distplot(df["Trust (Government Corruption)"])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(df["Generosity"])
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
sns.distplot(df["Dystopia Residual"])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %% [markdown]
# The data is not normalised. The building locks is out of the normalised curve.
#
# The normal distribution curve of Happiness score is irrelavent
#
# The normal distribution shows that the data is skewed.
#
# Data Cleaning:

# %%
df.corr()['Happiness Score'].sort_values()
# Out:
# Happiness Rank                  -0.992105
# Standard Error                  -0.177254
# Generosity                       0.180319
# Trust (Government Corruption)    0.395199
# Dystopia Residual                0.530474
# Freedom                          0.568211
# Health (Life Expectancy)         0.724200
# Family                           0.740605
# Economy (GDP per Capita)         0.780966
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64

# %%
delete = pd.DataFrame([["-0.992105", "Happiness Rank", "No", "Alot"],[ "-0.177254", "Standard Error", "No", "Alot"]], columns = ["Correlation with Target", "Column Name", "Normalised", "Outliers"])

# %%
delete
# Out:
#   Correlation with Target     Column Name Normalised Outliers
# 0               -0.992105  Happiness Rank         No     Alot
# 1               -0.177254  Standard Error         No     Alot

# %% [markdown]
# We are setting threshold of correlation as +/- 0.1.

# %%
df = df.drop(["Happiness Rank", "Standard Error"], axis= 1)

# %%
df
# Out:
#          Country                           Region  Happiness Score  \
# 0    Switzerland                   Western Europe            7.587
# 1        Iceland                   Western Europe            7.561
# 2        Denmark                   Western Europe            7.527
# 3         Norway                   Western Europe            7.522
# 4         Canada                    North America            7.427
# ..           ...                              ...              ...
# 153       Rwanda               Sub-Saharan Africa            3.465
# 154        Benin               Sub-Saharan Africa            3.340
# 155        Syria  Middle East and Northern Africa            3.006
# 156      Burundi               Sub-Saharan Africa            2.905
# 157         Togo               Sub-Saharan Africa            2.839
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# ...

# %%
df = df.drop(["Country","Region"], axis= 1)

# %%
df
# Out:
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# 2              7.527                   1.32548  1.36058
# 3              7.522                   1.45900  1.33095
# 4              7.427                   1.32629  1.32261
# ..               ...                       ...      ...
# 153            3.465                   0.22208  0.77370
# 154            3.340                   0.28665  0.35386
# 155            3.006                   0.66320  0.47489
# 156            2.905                   0.01530  0.41587
# 157            2.839                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %% [markdown]
# Removing Outliers:

# %% [markdown]
# IQR proximity rule

# %% [markdown]
# Z-score Technique

# %%
from scipy.stats import zscore

# %%
zscore(df)
# Out:
#      Happiness Score  Economy (GDP per Capita)    Family  \
# 0           1.937360                  1.369621  1.320281
# 1           1.914581                  1.135226  1.514458
# 2           1.884792                  1.192861  1.361054
# 3           1.880411                  1.525130  1.251922
# 4           1.797179                  1.194876  1.221204
# ..               ...                       ...       ...
# 153        -1.674055                 -1.552987 -0.800520
# 154        -1.783571                 -1.392303 -2.346860
# 155        -2.076199                 -0.455245 -1.901086
# 156        -2.164688                 -2.067566 -2.118467
# 157        -2.222513                 -1.586334 -3.134725
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 0                    1.263408  1.577438                       2.309652
# 1                    1.289434  1.332456                      -0.016480
# ...

# %%
z = np.abs(zscore(df))
z.shape
# Out:
# (158, 8)

# %%
type(z)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# numpy
# row wise - axis = 1
# column wise ---- axis = 0
#
# pandas
# row wise --- axis = 0
# column wise --- axis = 1

# %%
df_new = df[(z<3).all(axis=1)]

# %%
print("Old Dataframe", df.shape)
print(" New Dataframe", df_new.shape)
print("Total_Dropped_Rows", df.shape[0] - df_new.shape[0])
# Out:
# Old Dataframe (158, 8)
#  New Dataframe (152, 8)
# Total_Dropped_Rows 6

# %%
loss_percent = (158-152)/ 158*100
print(loss_percent, '%')
# Out:
# 3.79746835443038 %

# %%
np.where(z>3)
# Out:
# (array([ 27, 128, 147, 153, 155, 157]), array([5, 6, 2, 5, 7, 2]))

# %%
z.iloc[128]
# Out:
# Happiness Score                  0.936352
# Economy (GDP per Capita)         1.431049
# Family                           1.038637
# Health (Life Expectancy)         0.600092
# Freedom                          0.076923
# Trust (Government Corruption)    0.392117
# Generosity                       4.423262
# Dystopia Residual                1.234021
# Name: 128, dtype: float64

# %%
len(np.where(z>3))
# Out:
# 2

# %% [markdown]
# Model without outliers is df and model with desired outliers is df_new1:
#
# Dividing data in features and vectors

# %%
#  idependent column
x = df_new.iloc[:, :-1]

# %%
x
# Out:
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# 2              7.527                   1.32548  1.36058
# 3              7.522                   1.45900  1.33095
# 4              7.427                   1.32629  1.32261
# ..               ...                       ...      ...
# 150            3.655                   0.46534  0.77115
# 151            3.587                   0.25812  0.85188
# 152            3.575                   0.31982  0.30285
# 154            3.340                   0.28665  0.35386
# 156            2.905                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %%
# target
y = df_new.iloc[:, -1]

# %%
y
# Out:
# 0      2.51738
# 1      2.70201
# 2      2.49204
# 3      2.46531
# 4      2.45176
#         ...
# 150    1.41723
# 151    1.46494
# 152    1.95210
# 154    1.63328
# 156    1.83302
# Name: Dystopia Residual, Length: 152, dtype: float64

# %%
x.shape
# Out:
# (152, 7)

# %%
y.shape
# Out:
# (152,)

# %% [markdown]
# Transforming data to remove skewness:

# %%
from sklearn.preprocessing import power_transform

# %%
x = power_transform(x, method ='yeo-johnson')

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x
# Out:
# array([[ 1.8387073 ,  1.49611068,  1.66761865, ...,  1.76230968,
#          1.82206989,  0.65595135],
#        [ 1.81883275,  1.19771756,  2.02101058, ...,  1.44688502,
#          0.35523025,  1.57166845],
#        [ 1.79278922,  1.27024568,  1.7401529 , ...,  1.62217009,
#          1.95457488,  0.97742359],
#        ...,
#        [-1.79965538, -1.35114936, -2.09149024, ..., -1.27152319,
#         -0.16357633,  1.13659521],
#        [-2.06377822, -1.4183337 , -2.01503265, ...,  0.3154582 ,
#         -0.40394411, -0.32359556],
#        [-2.57588281, -1.91827051, -1.91154624, ..., -1.85450205,
#         -0.11827784, -0.18319784]])

# %%
x.ndim
# Out:
# 2

# %%
x.shape
# Out:
# (152, 7)

# %%
y.shape
# Out:
# (152,)

# %%
from sklearn.preprocessing import StandardScaler

# transform my dataset into a standard normal distribution
sc = StandardScaler()
x = sc.fit_transform(x)
x
# Out:
# array([[ 1.8387073 ,  1.49611068,  1.66761865, ...,  1.76230968,
#          1.82206989,  0.65595135],
#        [ 1.81883275,  1.19771756,  2.02101058, ...,  1.44688502,
#          0.35523025,  1.57166845],
#        [ 1.79278922,  1.27024568,  1.7401529 , ...,  1.62217009,
#          1.95457488,  0.97742359],
#        ...,
#        [-1.79965538, -1.35114936, -2.09149024, ..., -1.27152319,
#         -0.16357633,  1.13659521],
#        [-2.06377822, -1.4183337 , -2.01503265, ...,  0.3154582 ,
#         -0.40394411, -0.32359556],
#        [-2.57588281, -1.91827051, -1.91154624, ..., -1.85450205,
#         -0.11827784, -0.18319784]])

# %%
x.mean()
# Out:
# -1.3356066461656018e-17

# %%
X.mean()
# Out:
# 0.9819924987177839

# %%
y.mean()
# Out:
# 0.01

# %%
round(-1.33*10**(-17), 15)==0
# Out:
# True

# %%
x.std()
# Out:
# 1.0

# %%
X.std()
# Out:
# 0.7490175636001468

# %% [markdown]
# Since the outcome has only two classes we will use binary classification model.

# %%
from pandas import unique
pd.unique('Happiness Score')
# Out:
# array(['Happiness Score'], dtype=object)

# %%
pd.unique('Happiness Score')
# Out:
# array(['Happiness Score'], dtype=object)

# %%
df['Happiness Score'].unique()
# Out:
# array([7.587, 7.561, 7.527, 7.522, 7.427, 7.406, 7.378, 7.364, 7.286,
#        7.284, 7.278, 7.226, 7.2  , 7.187, 7.119, 6.983, 6.946, 6.94 ,
#        6.937, 6.901, 6.867, 6.853, 6.81 , 6.798, 6.786, 6.75 , 6.67 ,
#        6.611, 6.575, 6.574, 6.505, 6.485, 6.477, 6.455, 6.411, 6.329,
#        6.302, 6.298, 6.295, 6.269, 6.168, 6.13 , 6.123, 6.003, 5.995,
#        5.987, 5.984, 5.975, 5.96 , 5.948, 5.89 , 5.889, 5.878, 5.855,
#        5.848, 5.833, 5.828, 5.824, 5.813, 5.791, 5.77 , 5.759, 5.754,
#        5.716, 5.709, 5.695, 5.689, 5.605, 5.589, 5.548, 5.477, 5.474,
#        5.429, 5.399, 5.36 , 5.332, 5.286, 5.268, 5.253, 5.212, 5.194,
#        5.192, 5.14 , 5.129, 5.124, 5.123, 5.102, 5.098, 5.073, 5.057,
#        5.013, 5.007, 4.971, 4.959, 4.949, 4.898, 4.885, 4.876, 4.874,
#        4.867, 4.857, 4.839, 4.8  , 4.788, 4.786, 4.739, 4.715, 4.694,
#        4.686, 4.681, 4.677, 4.642, 4.633, 4.61 , 4.571, 4.565, 4.55 ,
# ...

# %%
df['Happiness Score'].value_counts()
# Out:
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# Name: Happiness Score, Length: 157, dtype: int64

# %%
# define dataset
import sklearn.datasets as sk
X, y = sk.make_classification(n_samples=10000, n_features=2, n_redundant=0,n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=1)

# %%
# Generate and plot a synthetic imbalanced classification dataset
from collections import Counter
from sklearn.datasets import make_classification
from matplotlib import pyplot
from numpy import where
# define dataset
X, y = make_classification(n_samples=10000, n_features=2, n_redundant=0,
	n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=1)
# summarize class distribution
counter = Counter(y)
print(counter)
# scatter plot of examples by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# Out:
# Counter({0: 9900, 1: 100})

# %%
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
from sklearn.metrics import accuracy_score

# %% [markdown]
# Splitting the dataframe:

# %%
# np.array(x)
# X = X.reshape(X.shape[:1000])
# X = X.transpose()

# %%
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=1/20, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
pred_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
lr = LogisticRegression()
for i in range(0,1000):
    x_train, x_test, y_train, y_test = train_test_split(X,y,random_state = i, test_size = 0.20)
    lr.fit(x_train, y_train)
    pred_train = lr.predict(x_train)
    pred_test = lr.predict(x_test)
    if round(accuracy_score(y_train, pred_train)*100,1)==round(accuracy_score(y_test, pred_test)*100, 1):
        print("At random state", i, "The model performs very well")
        print("At random_state:-", i)
        print("Training accuracy_score is:-", round(accuracy_score(y_train, pred_train)*100, 1))
        print("Testing accuracy_score is:-", round(accuracy_score(y_test, pred_test)*100, 1), '\n\n')
# Out:
# At random state 12 The model performs very well
# At random_state:- 12
# Training accuracy_score is:- 99.4
# Testing accuracy_score is:- 99.4
#
#
# At random state 19 The model performs very well
# At random_state:- 19
# Training accuracy_score is:- 99.5
# Testing accuracy_score is:- 99.5
#
#
# At random state 20 The model performs very well
# At random_state:- 20
# Training accuracy_score is:- 99.4
# Testing accuracy_score is:- 99.4
#
#
# At random state 29 The model performs very well
# At random_state:- 29
# Training accuracy_score is:- 99.4
# Testing accuracy_score is:- 99.4
#
#
# At random state 31 The model performs very well
# At random_state:- 31
# Training accuracy_score is:- 99.4
# Testing accuracy_score is:- 99.4
#
#
# At random state 42 The model performs very well
# At random_state:- 42
# Training accuracy_score is:- 99.4
# Testing accuracy_score is:- 99.4
#
#
# At random state 46 The model performs very well
# At random_state:- 46
# Training accuracy_score is:- 99.4
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size = .20, random_state=90)

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
pred_train = lr.predict(x_train)

# %%
pred_test = lr.predict(x_test)

# %%
accuracy_score(y_train, pred_train)
# Out:
# 0.994125

# %%
accuracy_score(y_test, pred_test)
# Out:
# 0.9965

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1983
#            1       0.92      0.65      0.76        17
#
#     accuracy                           1.00      2000
#    macro avg       0.96      0.82      0.88      2000
# weighted avg       1.00      1.00      1.00      2000

# %%
pred_lr = lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss = accuracy_score(y_test, pred_lr)

# %%
for j in range(4, 10):
    lsscore = cross_val_score(lr,X,y,cv=j)
    print(lsscore)
    lsc = lsscore.mean()
    print("At cv:-" , j)
    print("Cross validation score is:-", lsc*100)
    print("Accuracy_score is:-", lss*100)
    print("/n")
# Out:
# [0.9928 0.9944 0.9952 0.9952]
# At cv:- 4
# Cross validation score is:- 99.44000000000001
# Accuracy_score is:- 99.65
# /n
# [0.994 0.992 0.996 0.995 0.996]
# At cv:- 5
# Cross validation score is:- 99.46000000000001
# Accuracy_score is:- 99.65
# /n
# [0.9940012  0.99220156 0.99460108 0.99520096 0.99519808 0.99579832]
# At cv:- 6
# Cross validation score is:- 99.4500199599936
# Accuracy_score is:- 99.65
# /n
# [0.9930021  0.9930021  0.99440168 0.99510147 0.99509804 0.99509804
#  0.99579832]
# At cv:- 7
# Cross validation score is:- 99.45002493649665
# Accuracy_score is:- 99.65
# /n
# [0.9928 0.9936 0.9944 0.9944 0.996  0.9952 0.9952 0.9952]
# At cv:- 8
# Cross validation score is:- 99.46000000000001
# Accuracy_score is:- 99.65
# /n
# [0.99190647 0.99459946 0.99279928 0.99459946 0.99549955 0.99369937
#  0.99459946 0.99729973 0.99459946]
# At cv:- 9
# Cross validation score is:- 99.44002493774558
# Accuracy_score is:- 99.65
# /n

# %% [markdown]
# Since cross validation score accuracy score are almost the same, we are heading with a good approach

# %%
lsscore_selected = cross_val_score(lr,X,y,cv=9).mean()
print("The cv score is:", lsscore_selected, "\nThe accuracy score is: ", lss)
# Out:
# The cv score is: 0.9944002493774557
# The accuracy score is:  0.9965

# %%
from sklearn.metrics import confusion_matrix

# %%
def model_selection(algorithm_instance, x_train, y_train, x_test, y_test):
    algorithm_instance.fit(x_train,y_train)
    model_1_pred_train = algorithm_instance.predict(x_train)
    model_1_pred_test = algorithm_instance.predict(x_test)
    print('accuracy of the training model: ', accuracy_score(y_train, model_1_pred_train))
    print('accuracy of the test data: ', accuracy_score(y_test, model_1_pred_test))
    print('Classification report for test data \n', classification_report(y_test, model_1_pred_test))
    print('Classification report for the train data \n', classification_report(y_train, model_1_pred_train))
    print('Confusion matrix: \n', confusion_matrix(y_test, model_1_pred_test))

# %%
model_selection(lr, x_train, y_train, x_test, y_test)
# Out:
# accuracy of the training model:  0.994125
# accuracy of the test data:  0.9965
# Classification report for test data
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1983
#            1       0.92      0.65      0.76        17
#
#     accuracy                           1.00      2000
#    macro avg       0.96      0.82      0.88      2000
# weighted avg       1.00      1.00      1.00      2000
#
# Classification report for the train data
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7917
#            1       0.95      0.46      0.62        83
#
#     accuracy                           0.99      8000
#    macro avg       0.97      0.73      0.81      8000
# weighted avg       0.99      0.99      0.99      8000
#
# Confusion matrix:
#  [[1982    1]
#  [   6   11]]

# %% [markdown]
# The model with the outliers:
#
# AUC ROC Curve

# %%
import matplotlib.pyplot as plt

# %%
from turtle import color
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(pred_test, y_test)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color = 'darkorange', lw = 10, label='ROC curve(area =%0.2f)'% roc_auc)
plt.plot([0,1], [0,1], color ='navy', lw=10, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc ='lower right')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Since the model without outliers performing well, we will select that dataframe.

# %% [markdown]
# Model Saving

# %%
import pickle
fileName ='new_world_happiness_project.pkl'
pickle.dump(lr, open(fileName, 'wb'))
