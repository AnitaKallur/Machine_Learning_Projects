# %%
import pandas as pd

# %%
df = pd.read_csv("HR-Employee-Attrition.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
len(df)
# Out:
# 1470

# %%
df.duplicated().sum()
# Out:
# 0

# %%
unique_values = df["Age"].unique() ,
df["Attrition"].unique(),
df["BusinessTravel"].unique(),
df["DailyRate"].unique(),
df["Department"].unique(),
df["DistanceFromHome"].unique(),
df["Education"].unique(),
df["EducationField"].unique(),
df["EmployeeCount"].unique(),
df["EmployeeNumber"].unique(),
df["EnvironmentSatisfaction"].unique(),
df["Gender"].unique(),
df["HourlyRate"].unique(),
df["JobInvolvement"].unique(),
df["EducationField"].unique(),
df["JobLevel"].unique(),
df["JobRole"].unique(),
df["JobSatisfaction"].unique(),
df["MaritalStatus"].unique(),
df["MonthlyIncome"].unique(),
df["MonthlyRate"].unique(),
df["NumCompaniesWorked"].unique(),
df["Over18"].unique(),
df["OverTime"].unique(),
df["PercentSalaryHike"].unique(),
df["PerformanceRating"].unique(),
df["RelationshipSatisfaction"].unique(),
df["StandardHours"].unique(),
df["StockOptionLevel"].unique(),
df["TotalWorkingYears"].unique(),
df["TrainingTimesLastYear"].unique(),
df["WorkLifeBalance"].unique(),
df["YearsAtCompany"].unique(),
df["YearsInCurrentRole"].unique(),
df["YearsSinceLastPromotion"].unique(),
df["YearsWithCurrManager"].unique()
# Out:
# array([ 5,  7,  0,  2,  6,  8,  3, 11, 17,  1,  4, 12,  9, 10, 15, 13, 16,
#        14])

# %%
unique_values
# Out:
# (array([41, 49, 37, 33, 27, 32, 59, 30, 38, 36, 35, 29, 31, 34, 28, 22, 53,
#         24, 21, 42, 44, 46, 39, 43, 50, 26, 48, 55, 45, 56, 23, 51, 40, 54,
#         58, 20, 25, 19, 57, 52, 47, 18, 60]),)

# %% [markdown]
# # EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# sns.scatterplot(x= "Attrition", y= "Age", data = df)
plt.bar(df["Attrition"], df["Age"])
# Out:
# <BarContainer object of 1470 artists>

# %%
plt.bar(df["Attrition"], df["DailyRate"])
# Out:
# <BarContainer object of 1470 artists>

# %%
plt.bar(df["Attrition"], df["JobLevel"])
# Out:
# <BarContainer object of 1470 artists>

# %%
plt.bar(df["Attrition"], df["JobSatisfaction"])
# Out:
# <BarContainer object of 1470 artists>

# %%
plt.bar(df["Attrition"], df["Department"])
# Out:
# <BarContainer object of 1470 artists>

# %%
plt.bar(df["Attrition"], df["DistanceFromHome"])
# Out:
# <BarContainer object of 1470 artists>

# %%
plt.bar(df["Attrition"], df["Gender"])
# Out:
# <BarContainer object of 1470 artists>

# %%
plt.bar(df["Attrition"], df["MonthlyIncome"])
# Out:
# <BarContainer object of 1470 artists>

# %%
plt.bar(df["Attrition"], df["Education"])
# Out:
# <BarContainer object of 1470 artists>

# %%
plt.bar(df["Attrition"], df["TotalWorkingYears"])
# Out:
# <BarContainer object of 1470 artists>

# %%
plt.bar(df["Attrition"], df["TrainingTimesLastYear"])
# Out:
# <BarContainer object of 1470 artists>

# %%
plt.bar(df["Attrition"], df["YearsAtCompany"])
# Out:
# <BarContainer object of 1470 artists>

# %%
plt.bar(df["Attrition"], df["YearsInCurrentRole"])
# Out:
# <BarContainer object of 1470 artists>

# %%
plt.bar(df["Attrition"], df["YearsSinceLastPromotion"])
# Out:
# <BarContainer object of 1470 artists>

# %%
plt.bar(df["Attrition"], df["YearsWithCurrManager"])
# Out:
# <BarContainer object of 1470 artists>

# %%
df.hist(figsize=(15,15))
plt.tight_layout()
plt.show()

# %% [markdown]
# Monthly Income, Total working years, Year at company, Distance from home, Years since last promotion etc are right skewed.
# Most of the employees are age between 25-40 years old.
# Employee count and standard hours can be removed as they are redundant.

# %%
sns.kdeplot(df.loc[df['Attrition'] == 'No', 'Age'], label = 'Active Employee')
sns.kdeplot(df.loc[df['Attrition'] == 'Yes', 'Age'], label = 'Ex-Employee')
plt.legend()
plt.show()

# %% [markdown]
# Ex-Employees have an average age of 30 years, while the current employees are around the age of 37 years. Younger employees are more likely to take risk of changing the job, education and marital status influence the decision.

# %%
from matplotlib import rcParams
sns.boxenplot(y=df["MonthlyIncome"], x= df["JobRole"])
sns.set(rc={'figure.figsize':(20,12)})
# rcParams['figure.fizsize'] = 15,12
plt.grid(True, alpha = 1)
plt.tight_layout()
plt.show()

# %% [markdown]
# Following are some inferences that we can make from the above plot:
# 1. Managers & Reserch Directors earn relatively large sum. Monthly income parameter impacts directly towards Attrition rate.
# 2. Research Scientists, Lan Tech, Sale Rep are paid low and that would lead to attrition in respective departments. However, we need to verify these to conclude.

# %%
sns.catplot(x='JobRole', hue= 'Attrition', data = df, kind='count', height=7, aspect=2, legend=False)
plt.legend(loc= 'upper right', title = 'Attrition')
plt.tight_layout()
plt.show()

# %% [markdown]
# As we can see,
# Research Scientist, Lab Tech, Sales Rep, Sales executive have high attrition in theirn department. Whereas Manages & Research Directors have low attrition rate. Low Monthly income directly impacts the attrition rate.

# %%
sns.catplot(x='JobRole', hue='OverTime', data= df, kind='count', height= 7, aspect=2, legend=False)
plt.legend(loc='upper right', title = 'Over Time')
plt.tight_layout()
plt.show()

# %% [markdown]
# So we can conclude that Research scientists, Lab tech's deserve the pay rise, which eventually can reduce lower attrition rate in respective departments.

# %%
df['Attrition'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# This is an imbalanced dataset and we need to apply some sampling techniques to make the correction.

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# Lets convert some of object data to category.

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = df[col].astype('category')
        df[col] = df[col].cat.codes

# %%
df.corr()
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159205        0.024751   0.010661
# Attrition                -0.159205   1.000000        0.000074  -0.056652
# BusinessTravel            0.024751   0.000074        1.000000  -0.004086
# DailyRate                 0.010661  -0.056652       -0.004086   1.000000
# Department               -0.031882   0.063991       -0.009044   0.007109
# DistanceFromHome         -0.001686   0.077924       -0.024469  -0.004985
# Education                 0.208034  -0.031373        0.000757  -0.016806
# EducationField           -0.040873   0.026846        0.023724   0.037709
# EmployeeCount                  NaN        NaN             NaN        NaN
# EmployeeNumber           -0.010145  -0.010577       -0.015578  -0.050990
# EnvironmentSatisfaction   0.010146  -0.103369        0.004174   0.018355
# Gender                   -0.036311   0.029453       -0.032981  -0.011716
# ...

# %%
corr = df.corr()

# %%
sns.heatmap(corr, vmax = .5, linewidths = .2, cmap = "YlGnBu")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(25,15))
sns.heatmap(df.corr(), annot = True, linewidth = 0.5, linecolor = "black", fmt = '.2f')
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#                Age    Attrition  BusinessTravel    DailyRate   Department  \
# count  1470.000000  1470.000000     1470.000000  1470.000000  1470.000000
# mean     36.923810     0.161224        1.607483   802.485714     1.260544
# std       9.135373     0.367863        0.665455   403.509100     0.527792
# min      18.000000     0.000000        0.000000   102.000000     0.000000
# 25%      30.000000     0.000000        1.000000   465.000000     1.000000
# 50%      36.000000     0.000000        2.000000   802.000000     1.000000
# 75%      43.000000     0.000000        2.000000  1157.000000     2.000000
# max      60.000000     1.000000        2.000000  1499.000000     2.000000
#
#        DistanceFromHome    Education  EducationField  EmployeeCount  \
# count       1470.000000  1470.000000     1470.000000         1470.0
# mean           9.192517     2.912925        2.247619            1.0
# std            8.106864     1.024165        1.331369            0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int8
#  2   BusinessTravel            1470 non-null   int8
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int8
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   int8
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   int8
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# After performing EDA, we can conclude that younger employees take the risk of changing jobs in the distribution and married employees between the age of 30-40 seek stability in the job. HR department should come up with employee retention paln to attract younger employees to stay with the company.
#
# Attrition rate is high in Lab Tech, Research scientist, sale rep as they work overtime with low income, to retain employees in these departments, HR Department should consider some work life balance measures and they should be paid according to the market standards.

# %%
from sklearn.linear_model import LogisticRegression
from plot_metric.functions import BinaryClassification as BC
import numpy as np
from sklearn.model_selection import train_test_split

# This is a dataset balancing measure

df = df[(df['Attrition']!= 0)| (np.random.rand(len(df)) < .33)]

# %%
X = df.drop('Attrition', axis=1)
y = df['Attrition']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y , train_size= 0.8, random_state= 42, stratify=y)

# Data Normalization
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (0,1))
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
# Define parameter for hyper-parameter tuning
params = {
    'solver': ['newton-cg', 'liblinear'],
    'penalty': ['l2'],
    'C': np.logspace(-4.5,4.5,50),
    'class_weight': ['balanced'],
    'tol': [0.0001, 0.001, 0.01, 0.1],
    'fit_intercept': [True, False],
'intercept_scaling' : [1,2,3]
}

# Initializing Grid Search with Logistic Regression and keeping roc_auc as the performance 
grid_search = GridSearchCV(estimator = LogisticRegression(),
                           param_grid= params,
                           cv = 5,
                           n_jobs= -1,
                           verbose=0,
                           scoring="roc_auc",
                           return_train_score = True)

# Training
grid_search.fit(X_train, y_train)
# Best performing parameter
print('='*20)
print("best params: " + str(grid_search.best_estimator_))
print('best score: ', grid_search.best_score_)
print('='*20)
# Out:
# ...
# best params: LogisticRegression(C=0.3473892112083119, class_weight='balanced',
#                    solver='newton-cg', tol=0.1)
# best score:  0.8141163444384182
# ...

# %%
from plot_metric.functions import BinaryClassification as BC, confusion_matrix
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score, classification_report
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)
pd.DataFrame(confusion_matrix(y_test,y_pred), columns=["Predicted A", "Predicted T"], index=["Actual A","Actual T"])
# Out:
#           Predicted A  Predicted T
# Actual A           67           16
# Actual T            9           39

# %%
logreg_grid_score = accuracy_score(y_test, y_pred)
print('Model Accuracy:', logreg_grid_score)
print('Classification Report:\n', classification_report(y_test, y_pred))
# Out:
# Model Accuracy: 0.8091603053435115
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.81      0.84        83
#            1       0.71      0.81      0.76        48
#
#     accuracy                           0.81       131
#    macro avg       0.80      0.81      0.80       131
# weighted avg       0.82      0.81      0.81       131
